# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observations:
# 1) Southern Hemisphere climates tend to be slightly milder than those at similar latitudes in the Northern Hemisphere. This is because the Southern Hemisphere has significantly more water and less land. Also, water heats up and cools down more slowly than land
#
# 2) Highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops. This happens as equatorial region receives sunlight straight with less or no angle due to curvature shape of earth
#
# 3) Latitude doesn't have a strong iinfluence on wind speed. The speed of the wind is controlled by the strength of the air pressure gradient, the stronger the pressure gradient the higher the wind speed

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import scipy.stats as st
from scipy.stats import linregress

#import api_keys
from config import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %%
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# -----------------------------
# Processing Record 1 of Set 1 : tazovskiy
# Processing Record 2 of Set 1 : olinda
# Processing Record 3 of Set 1 : port alfred
# Processing Record 4 of Set 1 : abong mbang
# Processing Record 5 of Set 1 : lompoc
# Processing Record 6 of Set 1 : norman wells
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 1 : bambous virieux
# Processing Record 8 of Set 1 : gondanglegi
# Processing Record 9 of Set 1 : bilibino
# Processing Record 10 of Set 1 : praya
# Processing Record 11 of Set 1 : albany
# Processing Record 12 of Set 1 : qaanaaq
# Processing Record 13 of Set 1 : busselton
# Processing Record 14 of Set 1 : lahat
# Processing Record 15 of Set 1 : vaini
# Processing Record 16 of Set 1 : sitka
# Processing Record 17 of Set 1 : hobart
# Processing Record 18 of Set 1 : atuona
# Processing Record 19 of Set 1 : barrow
# Processing Record 20 of Set 1 : hermanus
# Processing Record 21 of Set 1 : te anau
# Processing Record 22 of Set 1 : cayenne
# Processing Record 23 of Set 1 : lugoba
# Processing Record 24 of Set 1 : verkhnevilyuysk
# Processing Record 25 of Set 1 : puerto ayora
# Processing Record 26 of Set 1 : ponta do sol
# Processing Record 27 of Set 1 : punta arenas
# Processing Record 28 of Set 1 : dzilam gonzalez
# Processing Record 29 of Set 1 : vestmannaeyjar
# Processing Record 30 of Set 1 : ushuaia
# City not found. Skipping...
# Processing Record 31 of Set 1 : mecca
# City not found. Skipping...
# Processing Record 32 of Set 1 : rawson
# Processing Record 33 of Set 1 : aldan
# Processing Record 34 of Set 1 : rikitea
# Processing Record 35 of Set 1 : roma
# Processing Record 36 of Set 1 : arrifes
# Processing Record 37 of Set 1 : yellowknife
# Processing Record 38 of Set 1 : mbumi
# Processing Record 39 of Set 1 : mildura
# Processing Record 40 of Set 1 : kupino
# Processing Record 41 of Set 1 : cape town
# Processing Record 42 of Set 1 : kapaa
# Processing Record 43 of Set 1 : grindavik
# Processing Record 44 of Set 1 : guerrero negro
# Processing Record 45 of Set 1 : khatanga
# Processing Record 46 of Set 1 : kushva
# Processing Record 47 of Set 1 : aviles
# Processing Record 48 of Set 1 : college
# Processing Record 49 of Set 1 : vostok
# Processing Record 50 of Set 1 : butaritari
# Processing Record 0 of Set 2 : bengkulu
# Processing Record 1 of Set 2 : manadhoo
# Processing Record 2 of Set 2 : namibe
# City not found. Skipping...
# Processing Record 3 of Set 2 : hithadhoo
# Processing Record 4 of Set 2 : samarai
# City not found. Skipping...
# Processing Record 5 of Set 2 : brae
# Processing Record 6 of Set 2 : port lincoln
# Processing Record 7 of Set 2 : tonota
# Processing Record 8 of Set 2 : beringovskiy
# Processing Record 9 of Set 2 : kodiak
# Processing Record 10 of Set 2 : rocha
# Processing Record 11 of Set 2 : bondo
# Processing Record 12 of Set 2 : pandan
# City not found. Skipping...
# Processing Record 13 of Set 2 : mataura
# Processing Record 14 of Set 2 : port elizabeth
# Processing Record 15 of Set 2 : castro
# Processing Record 16 of Set 2 : severo-kurilsk
# Processing Record 17 of Set 2 : los llanos de aridane
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 2 : saint-philippe
# Processing Record 19 of Set 2 : bluff
# Processing Record 20 of Set 2 : san quintin
# Processing Record 21 of Set 2 : mount isa
# Processing Record 22 of Set 2 : avarua
# Processing Record 23 of Set 2 : grado
# Processing Record 24 of Set 2 : ribeira grande
# Processing Record 25 of Set 2 : alamos
# Processing Record 26 of Set 2 : cherskiy
# City not found. Skipping...
# Processing Record 27 of Set 2 : thompson
# Processing Record 28 of Set 2 : bethel
# City not found. Skipping...
# Processing Record 29 of Set 2 : gigmoto
# Processing Record 30 of Set 2 : east london
# Processing Record 31 of Set 2 : georgetown
# Processing Record 32 of Set 2 : nikolskoye
# Processing Record 33 of Set 2 : verkh-usugli
# Processing Record 34 of Set 2 : shache
# Processing Record 35 of Set 2 : jamestown
# Processing Record 36 of Set 2 : antalaha
# Processing Record 37 of Set 2 : kaitangata
# Processing Record 38 of Set 2 : klaksvik
# Processing Record 39 of Set 2 : bom jesus
# Processing Record 40 of Set 2 : turan
# Processing Record 41 of Set 2 : kiruna
# Processing Record 42 of Set 2 : mahebourg
# Processing Record 43 of Set 2 : fairbanks
# Processing Record 44 of Set 2 : bredasdorp
# City not found. Skipping...
# Processing Record 45 of Set 2 : ilulissat
# Processing Record 46 of Set 2 : naze
# Processing Record 47 of Set 2 : carnarvon
# Processing Record 48 of Set 2 : kiyasovo
# Processing Record 49 of Set 2 : baykit
# City not found. Skipping...
# Processing Record 50 of Set 2 : harper
# Processing Record 0 of Set 3 : sao lourenco do sul
# Processing Record 1 of Set 3 : saskylakh
# Processing Record 2 of Set 3 : great yarmouth
# City not found. Skipping...
# Processing Record 3 of Set 3 : manbij
# Processing Record 4 of Set 3 : haines junction
# Processing Record 5 of Set 3 : hami
# Processing Record 6 of Set 3 : kangaatsiaq
# Processing Record 7 of Set 3 : tuktoyaktuk
# Processing Record 8 of Set 3 : chuy
# Processing Record 9 of Set 3 : arua
# Processing Record 10 of Set 3 : mafinga
# Processing Record 11 of Set 3 : vung tau
# Processing Record 12 of Set 3 : sakakah
# Processing Record 13 of Set 3 : shimoda
# City not found. Skipping...
# Processing Record 14 of Set 3 : upernavik
# Processing Record 15 of Set 3 : barranca
# Processing Record 16 of Set 3 : divnomorskoye
# City not found. Skipping...
# Processing Record 17 of Set 3 : onda
# Processing Record 18 of Set 3 : constitucion
# Processing Record 19 of Set 3 : lamu
# Processing Record 20 of Set 3 : jalu
# City not found. Skipping...
# Processing Record 21 of Set 3 : kahului
# Processing Record 22 of Set 3 : liverpool
# Processing Record 23 of Set 3 : port augusta
# City not found. Skipping...
# Processing Record 24 of Set 3 : mar del plata
# Processing Record 25 of Set 3 : taber
# Processing Record 26 of Set 3 : fundao
# Processing Record 27 of Set 3 : richards bay
# Processing Record 28 of Set 3 : saldanha
# Processing Record 29 of Set 3 : puerto leguizamo
# Processing Record 30 of Set 3 : half moon bay
# Processing Record 31 of Set 3 : havoysund
# City not found. Skipping...
# Processing Record 32 of Set 3 : cookeville
# Processing Record 33 of Set 3 : saint george
# Processing Record 34 of Set 3 : arraial do cabo
# Processing Record 35 of Set 3 : longyearbyen
# Processing Record 36 of Set 3 : esperance
# Processing Record 37 of Set 3 : meulaboh
# Processing Record 38 of Set 3 : ostrovnoy
# City not found. Skipping...
# Processing Record 39 of Set 3 : aktau
# Processing Record 40 of Set 3 : vilyuysk
# Processing Record 41 of Set 3 : mangrol
# Processing Record 42 of Set 3 : alofi
# Processing Record 43 of Set 3 : tasiilaq
# Processing Record 44 of Set 3 : lavrentiya
# Processing Record 45 of Set 3 : edd
# Processing Record 46 of Set 3 : ebebiyin
# Processing Record 47 of Set 3 : pisco
# Processing Record 48 of Set 3 : casablanca
# Processing Record 49 of Set 3 : san jose
# Processing Record 50 of Set 3 : hilo
# Processing Record 0 of Set 4 : raca
# Processing Record 1 of Set 4 : fort walton beach
# Processing Record 2 of Set 4 : ostersund
# City not found. Skipping...
# Processing Record 3 of Set 4 : smithers
# City not found. Skipping...
# Processing Record 4 of Set 4 : tarakan
# Processing Record 5 of Set 4 : pevek
# Processing Record 6 of Set 4 : alice springs
# City not found. Skipping...
# Processing Record 7 of Set 4 : laguna
# Processing Record 8 of Set 4 : indramayu
# Processing Record 9 of Set 4 : kjustendil
# Processing Record 10 of Set 4 : tutayev
# Processing Record 11 of Set 4 : el alto
# Processing Record 12 of Set 4 : eyl
# Processing Record 13 of Set 4 : general roca
# Processing Record 14 of Set 4 : talnakh
# Processing Record 15 of Set 4 : karatuzskoye
# Processing Record 16 of Set 4 : cabo san lucas
# Processing Record 17 of Set 4 : san patricio
# Processing Record 18 of Set 4 : moncao
# Processing Record 19 of Set 4 : el dorado
# Processing Record 20 of Set 4 : olafsvik
# Processing Record 21 of Set 4 : jensen beach
# Processing Record 22 of Set 4 : mandurah
# Processing Record 23 of Set 4 : corinto
# Processing Record 24 of Set 4 : port shepstone
# Processing Record 25 of Set 4 : pangnirtung
# Processing Record 26 of Set 4 : jawhar
# Processing Record 27 of Set 4 : port blair
# Processing Record 28 of Set 4 : port hardy
# Processing Record 29 of Set 4 : santa maria do suacui
# Processing Record 30 of Set 4 : la rochelle
# Processing Record 31 of Set 4 : dongsheng
# Processing Record 32 of Set 4 : faya
# Processing Record 33 of Set 4 : mackay
# Processing Record 34 of Set 4 : ariquemes
# Processing Record 35 of Set 4 : moerai
# Processing Record 36 of Set 4 : aripuana
# Processing Record 37 of Set 4 : dawlatabad
# Processing Record 38 of Set 4 : yartsevo
# Processing Record 39 of Set 4 : porto novo
# Processing Record 40 of Set 4 : atikokan
# City not found. Skipping...
# Processing Record 41 of Set 4 : podgornoye
# Processing Record 42 of Set 4 : krutikha
# Processing Record 43 of Set 4 : avera
# Processing Record 44 of Set 4 : yar-sale
# City not found. Skipping...
# Processing Record 45 of Set 4 : santa isabel
# Processing Record 46 of Set 4 : artyom
# Processing Record 47 of Set 4 : belyy yar
# Processing Record 48 of Set 4 : mocorito
# Processing Record 49 of Set 4 : luba
# Processing Record 50 of Set 4 : chingola
# Processing Record 0 of Set 5 : new norfolk
# Processing Record 1 of Set 5 : bethanien
# Processing Record 2 of Set 5 : bardiyah
# Processing Record 3 of Set 5 : seoul
# Processing Record 4 of Set 5 : kitimat
# City not found. Skipping...
# Processing Record 5 of Set 5 : anapskaya
# Processing Record 6 of Set 5 : mbandaka
# Processing Record 7 of Set 5 : coquimbo
# Processing Record 8 of Set 5 : homer
# Processing Record 9 of Set 5 : kruisfontein
# Processing Record 10 of Set 5 : dikson
# Processing Record 11 of Set 5 : ankang
# Processing Record 12 of Set 5 : honiara
# Processing Record 13 of Set 5 : inhambane
# Processing Record 14 of Set 5 : sao joao do piaui
# Processing Record 15 of Set 5 : guozhen
# Processing Record 16 of Set 5 : tortosa
# Processing Record 17 of Set 5 : hamilton
# Processing Record 18 of Set 5 : itarema
# Processing Record 19 of Set 5 : touros
# Processing Record 20 of Set 5 : ancud
# City not found. Skipping...
# Processing Record 21 of Set 5 : hofn
# Processing Record 22 of Set 5 : domoni
# Processing Record 23 of Set 5 : taywarah
# Processing Record 24 of Set 5 : gizo
# Processing Record 25 of Set 5 : dawei
# Processing Record 26 of Set 5 : karratha
# Processing Record 27 of Set 5 : yulara
# Processing Record 28 of Set 5 : katsuura
# Processing Record 29 of Set 5 : teknaf
# Processing Record 30 of Set 5 : puerto ayacucho
# Processing Record 31 of Set 5 : hirara
# Processing Record 32 of Set 5 : saint-pierre
# Processing Record 33 of Set 5 : lake city
# Processing Record 34 of Set 5 : sao filipe
# Processing Record 35 of Set 5 : indianola
# Processing Record 36 of Set 5 : waingapu
# Processing Record 37 of Set 5 : zhigansk
# City not found. Skipping...
# Processing Record 38 of Set 5 : natal
# Processing Record 39 of Set 5 : inta
# Processing Record 40 of Set 5 : loukhi
# Processing Record 41 of Set 5 : atlantic city
# Processing Record 42 of Set 5 : kpandu
# Processing Record 43 of Set 5 : vardo
# Processing Record 44 of Set 5 : riyadh
# Processing Record 45 of Set 5 : tucumcari
# Processing Record 46 of Set 5 : kaduna
# Processing Record 47 of Set 5 : dzaoudzi
# Processing Record 48 of Set 5 : airai
# Processing Record 49 of Set 5 : neuquen
# Processing Record 50 of Set 5 : cape canaveral
# Processing Record 0 of Set 6 : port macquarie
# Processing Record 1 of Set 6 : lagoa
# Processing Record 2 of Set 6 : victoria
# Processing Record 3 of Set 6 : mineral del monte
# Processing Record 4 of Set 6 : kupang
# Processing Record 5 of Set 6 : kiama
# Processing Record 6 of Set 6 : kamenka
# Processing Record 7 of Set 6 : vila velha
# Processing Record 8 of Set 6 : vogan
# Processing Record 9 of Set 6 : lichinga
# City not found. Skipping...
# Processing Record 10 of Set 6 : vila
# Processing Record 11 of Set 6 : kholm
# Processing Record 12 of Set 6 : dustlik
# Processing Record 13 of Set 6 : nobres
# Processing Record 14 of Set 6 : wanaka
# Processing Record 15 of Set 6 : shar
# Processing Record 16 of Set 6 : placerville
# Processing Record 17 of Set 6 : chiredzi
# Processing Record 18 of Set 6 : sur
# Processing Record 19 of Set 6 : noumea
# Processing Record 20 of Set 6 : mahibadhoo
# Processing Record 21 of Set 6 : ilhabela
# Processing Record 22 of Set 6 : ulladulla
# Processing Record 23 of Set 6 : luganville
# Processing Record 24 of Set 6 : khelyulya
# Processing Record 25 of Set 6 : oktyabrskiy
# Processing Record 26 of Set 6 : solnechnyy
# Processing Record 27 of Set 6 : leshukonskoye
# Processing Record 28 of Set 6 : rio grande
# Processing Record 29 of Set 6 : ugoofaaru
# Processing Record 30 of Set 6 : tiznit
# Processing Record 31 of Set 6 : fukue
# Processing Record 32 of Set 6 : loei
# Processing Record 33 of Set 6 : klamath falls
# Processing Record 34 of Set 6 : ayagoz
# Processing Record 35 of Set 6 : torbay
# Processing Record 36 of Set 6 : alyangula
# Processing Record 37 of Set 6 : namatanai
# Processing Record 38 of Set 6 : yulin
# Processing Record 39 of Set 6 : iqaluit
# Processing Record 40 of Set 6 : hit
# Processing Record 41 of Set 6 : nome
# Processing Record 42 of Set 6 : bud
# Processing Record 43 of Set 6 : morondava
# Processing Record 44 of Set 6 : celestun
# Processing Record 45 of Set 6 : kirkwall
# Processing Record 46 of Set 6 : cleveland
# Processing Record 47 of Set 6 : imbituba
# City not found. Skipping...
# Processing Record 48 of Set 6 : broome
# Processing Record 49 of Set 6 : puerto escondido
# Processing Record 50 of Set 6 : ixtapa
# Processing Record 0 of Set 7 : haukipudas
# Processing Record 1 of Set 7 : morwell
# Processing Record 2 of Set 7 : saint anthony
# Processing Record 3 of Set 7 : sembe
# Processing Record 4 of Set 7 : la ronge
# Processing Record 5 of Set 7 : batagay-alyta
# Processing Record 6 of Set 7 : carutapera
# Processing Record 7 of Set 7 : aksarka
# Processing Record 8 of Set 7 : black river
# Processing Record 9 of Set 7 : conceicao do araguaia
# Processing Record 10 of Set 7 : evensk
# Processing Record 11 of Set 7 : balkhash
# Processing Record 12 of Set 7 : yeniseysk
# Processing Record 13 of Set 7 : galesong
# City not found. Skipping...
# Processing Record 14 of Set 7 : marapanim
# Processing Record 15 of Set 7 : troitsko-pechorsk
# City not found. Skipping...
# Processing Record 16 of Set 7 : north bend
# Processing Record 17 of Set 7 : flin flon
# Processing Record 18 of Set 7 : chulym
# City not found. Skipping...
# Processing Record 19 of Set 7 : boguchany
# Processing Record 20 of Set 7 : acapulco
# Processing Record 21 of Set 7 : paamiut
# Processing Record 22 of Set 7 : dongling
# Processing Record 23 of Set 7 : kodinsk
# City not found. Skipping...
# Processing Record 24 of Set 7 : verkhoyansk
# Processing Record 25 of Set 7 : yerofey pavlovich
# Processing Record 26 of Set 7 : bac lieu
# Processing Record 27 of Set 7 : faanui
# Processing Record 28 of Set 7 : steamboat springs
# Processing Record 29 of Set 7 : mandera
# Processing Record 30 of Set 7 : semme
# Processing Record 31 of Set 7 : boli
# Processing Record 32 of Set 7 : musoma
# Processing Record 33 of Set 7 : meaford
# Processing Record 34 of Set 7 : teya
# City not found. Skipping...
# Processing Record 35 of Set 7 : rajbiraj
# Processing Record 36 of Set 7 : port moresby
# Processing Record 37 of Set 7 : ibaiti
# Processing Record 38 of Set 7 : sumbe
# Processing Record 39 of Set 7 : ruwi
# Processing Record 40 of Set 7 : dunedin
# Processing Record 41 of Set 7 : codrington
# Processing Record 42 of Set 7 : pringsewu
# Processing Record 43 of Set 7 : srednekolymsk
# Processing Record 44 of Set 7 : buenos aires
# Processing Record 45 of Set 7 : kavieng
# Processing Record 46 of Set 7 : nanortalik
# Processing Record 47 of Set 7 : berezovyy
# Processing Record 48 of Set 7 : lorvao
# Processing Record 49 of Set 7 : cidreira
# Processing Record 50 of Set 7 : shetpe
# Processing Record 0 of Set 8 : aswan
# City not found. Skipping...
# Processing Record 1 of Set 8 : pecos
# Processing Record 2 of Set 8 : aras
# Processing Record 3 of Set 8 : lebu
# Processing Record 4 of Set 8 : whitecourt
# Processing Record 5 of Set 8 : igunga
# Processing Record 6 of Set 8 : romitan
# Processing Record 7 of Set 8 : pujehun
# Processing Record 8 of Set 8 : selimbar
# Processing Record 9 of Set 8 : mwanza
# Processing Record 10 of Set 8 : paraiso
# Processing Record 11 of Set 8 : adrar
# Processing Record 12 of Set 8 : niamey
# Processing Record 13 of Set 8 : lethem
# Processing Record 14 of Set 8 : ahipara
# Processing Record 15 of Set 8 : acari
# Processing Record 16 of Set 8 : clyde river
# Processing Record 17 of Set 8 : rio gallegos
# Processing Record 18 of Set 8 : altamira
# Processing Record 19 of Set 8 : nokaneng
# Processing Record 20 of Set 8 : buraydah
# Processing Record 21 of Set 8 : narsaq
# Processing Record 22 of Set 8 : mumford
# Processing Record 23 of Set 8 : rajauri
# Processing Record 24 of Set 8 : tinaquillo
# Processing Record 25 of Set 8 : bend
# Processing Record 26 of Set 8 : benjamin constant
# City not found. Skipping...
# Processing Record 27 of Set 8 : jiaojiang
# Processing Record 28 of Set 8 : la orilla
# Processing Record 29 of Set 8 : chapais
# Processing Record 30 of Set 8 : grootfontein
# Processing Record 31 of Set 8 : saquarema
# Processing Record 32 of Set 8 : vallenar
# Processing Record 33 of Set 8 : solano
# Processing Record 34 of Set 8 : sidrolandia
# Processing Record 35 of Set 8 : watsa
# Processing Record 36 of Set 8 : padang
# Processing Record 37 of Set 8 : nouadhibou
# Processing Record 38 of Set 8 : salcedo
# Processing Record 39 of Set 8 : kyra
# Processing Record 40 of Set 8 : luderitz
# Processing Record 41 of Set 8 : san andres
# Processing Record 42 of Set 8 : agua branca
# Processing Record 43 of Set 8 : yangambi
# Processing Record 44 of Set 8 : la tuque
# Processing Record 45 of Set 8 : kavaratti
# Processing Record 46 of Set 8 : camacupa
# Processing Record 47 of Set 8 : ercis
# Processing Record 48 of Set 8 : houma
# Processing Record 49 of Set 8 : biysk
# Processing Record 50 of Set 8 : waynesboro
# Processing Record 0 of Set 9 : pedra azul
# Processing Record 1 of Set 9 : port hawkesbury
# City not found. Skipping...
# Processing Record 2 of Set 9 : souillac
# Processing Record 3 of Set 9 : hyeres
# Processing Record 4 of Set 9 : impfondo
# Processing Record 5 of Set 9 : bendigo
# Processing Record 6 of Set 9 : havelock
# Processing Record 7 of Set 9 : coroneo
# Processing Record 8 of Set 9 : aitape
# Processing Record 9 of Set 9 : poum
# Processing Record 10 of Set 9 : chapleau
# Processing Record 11 of Set 9 : dharchula
# Processing Record 12 of Set 9 : aliwal north
# Processing Record 13 of Set 9 : dudinka
# City not found. Skipping...
# Processing Record 14 of Set 9 : alta floresta
# Processing Record 15 of Set 9 : acarau
# Processing Record 16 of Set 9 : krasnoselkup
# Processing Record 17 of Set 9 : sola
# Processing Record 18 of Set 9 : manyana
# Processing Record 19 of Set 9 : turka
# Processing Record 20 of Set 9 : bambanglipuro
# Processing Record 21 of Set 9 : marsa matruh
# Processing Record 22 of Set 9 : geraldton
# Processing Record 23 of Set 9 : tubmanburg
# Processing Record 24 of Set 9 : dingle
# Processing Record 25 of Set 9 : comodoro rivadavia
# Processing Record 26 of Set 9 : sao joao da barra
# Processing Record 27 of Set 9 : tearce
# Processing Record 28 of Set 9 : kaeo
# Processing Record 29 of Set 9 : ingham
# Processing Record 30 of Set 9 : santa cruz
# City not found. Skipping...
# Processing Record 31 of Set 9 : ilam
# Processing Record 32 of Set 9 : frumusita
# City not found. Skipping...
# Processing Record 33 of Set 9 : novikovo
# Processing Record 34 of Set 9 : hambantota
# Processing Record 35 of Set 9 : nova prata
# City not found. Skipping...
# Processing Record 36 of Set 9 : the valley
# Processing Record 37 of Set 9 : mirador
# City not found. Skipping...
# Processing Record 38 of Set 9 : ledyard
# Processing Record 39 of Set 9 : komatipoort
# Processing Record 40 of Set 9 : muli
# Processing Record 41 of Set 9 : iwo
# Processing Record 42 of Set 9 : nyaunglebin
# Processing Record 43 of Set 9 : kayerkan
# Processing Record 44 of Set 9 : clinton
# Processing Record 45 of Set 9 : goldsboro
# Processing Record 46 of Set 9 : provideniya
# Processing Record 47 of Set 9 : mashivka
# Processing Record 48 of Set 9 : bousso
# Processing Record 49 of Set 9 : tekeli
# Processing Record 50 of Set 9 : arman
# Processing Record 0 of Set 10 : tiksi
# Processing Record 1 of Set 10 : mount gambier
# Processing Record 2 of Set 10 : savonlinna
# Processing Record 3 of Set 10 : salinas
# Processing Record 4 of Set 10 : maniitsoq
# Processing Record 5 of Set 10 : saint-augustin
# Processing Record 6 of Set 10 : muzhi
# Processing Record 7 of Set 10 : betsiamites
# Processing Record 8 of Set 10 : narrabri
# Processing Record 9 of Set 10 : chara
# Processing Record 10 of Set 10 : nizwa
# Processing Record 11 of Set 10 : hobyo
# Processing Record 12 of Set 10 : rajapur
# Processing Record 13 of Set 10 : ouesso
# Processing Record 14 of Set 10 : paita
# Processing Record 15 of Set 10 : murray bridge
# Processing Record 16 of Set 10 : mandalgovi
# Processing Record 17 of Set 10 : kurchum
# Processing Record 18 of Set 10 : nankana sahib
# Processing Record 19 of Set 10 : antsohihy
# Processing Record 20 of Set 10 : luanda
# Processing Record 21 of Set 10 : chauk
# Processing Record 22 of Set 10 : hualmay
# Processing Record 23 of Set 10 : margate
# Processing Record 24 of Set 10 : bubaque
# Processing Record 25 of Set 10 : petropavlovsk-kamchatskiy
# Processing Record 26 of Set 10 : san cristobal
# City not found. Skipping...
# Processing Record 27 of Set 10 : lesnyye polyany
# Processing Record 28 of Set 10 : oktyabrskoye
# Processing Record 29 of Set 10 : kalmunai
# Processing Record 30 of Set 10 : kenai
# Processing Record 31 of Set 10 : pyaozerskiy
# Processing Record 32 of Set 10 : vanavara
# Processing Record 33 of Set 10 : kota kinabalu
# Processing Record 34 of Set 10 : chimbote
# Processing Record 35 of Set 10 : zhanakorgan
# Processing Record 36 of Set 10 : hua hin
# Processing Record 37 of Set 10 : sutysky
# Processing Record 38 of Set 10 : byron bay
# Processing Record 39 of Set 10 : brownsville
# Processing Record 40 of Set 10 : ketchikan
# Processing Record 41 of Set 10 : oil city
# Processing Record 42 of Set 10 : nemuro
# Processing Record 43 of Set 10 : sorland
# Processing Record 44 of Set 10 : rosetta
# Processing Record 45 of Set 10 : thanh hoa
# Processing Record 46 of Set 10 : atar
# Processing Record 47 of Set 10 : matagami
# Processing Record 48 of Set 10 : diamantina
# Processing Record 49 of Set 10 : trinidad
# Processing Record 50 of Set 10 : chokurdakh
# City not found. Skipping...
# Processing Record 0 of Set 11 : mbengwi
# Processing Record 1 of Set 11 : yamada
# Processing Record 2 of Set 11 : aberdeen
# Processing Record 3 of Set 11 : muyezerskiy
# Processing Record 4 of Set 11 : crotone
# Processing Record 5 of Set 11 : terney
# Processing Record 6 of Set 11 : samoylovka
# Processing Record 7 of Set 11 : ipixuna
# Processing Record 8 of Set 11 : aklavik
# Processing Record 9 of Set 11 : tomatlan
# Processing Record 10 of Set 11 : menzelinsk
# Processing Record 11 of Set 11 : mujiayingzi
# City not found. Skipping...
# Processing Record 12 of Set 11 : astana
# Processing Record 13 of Set 11 : kilimatinde
# Processing Record 14 of Set 11 : huaicheng
# Processing Record 15 of Set 11 : tuatapere
# Processing Record 16 of Set 11 : santiago
# City not found. Skipping...
# Processing Record 17 of Set 11 : tromso
# Processing Record 18 of Set 11 : toora-khem
# Processing Record 19 of Set 11 : atherton
# Processing Record 20 of Set 11 : hasaki
# Processing Record 21 of Set 11 : bulungu
# Processing Record 22 of Set 11 : maumere
# Processing Record 23 of Set 11 : uruzgan
# Processing Record 24 of Set 11 : skjervoy
# Processing Record 25 of Set 11 : kaduqli
# Processing Record 26 of Set 11 : miguel hidalgo
# Processing Record 27 of Set 11 : lakes entrance
# Processing Record 28 of Set 11 : butka
# Processing Record 29 of Set 11 : prince albert
# City not found. Skipping...
# Processing Record 30 of Set 11 : mananjary
# Processing Record 31 of Set 11 : agadez
# City not found. Skipping...
# Processing Record 32 of Set 11 : gwadar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_dict = pd.DataFrame({ 
                "City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list
})

# %%
# Count data
weather_dict.count()
# Out:
# City          542
# Cloudiness    542
# Country       542
# Date          542
# Humidity      542
# Lat           542
# Lng           542
# Max Temp      542
# Wind Speed    542
# dtype: int64

# %%
# Display the Data Frame
weather_dict
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0         Tazovsky          99      RU  1600183136        84  67.47   78.70
# 1           Olinda          40      BR  1600183137        69  -8.01  -34.86
# 2      Port Alfred         100      ZA  1600183137        68 -33.59   26.89
# 3      Abong Mbang          61      CM  1600183137        80   3.98   13.18
# 4           Lompoc          90      US  1600182934       100  34.64 -120.46
# ..             ...         ...     ...         ...       ...    ...     ...
# 537          Butka         100      RU  1600183263        95  56.72   63.79
# 538  Prince Albert          90      CA  1600183264        81  53.20 -105.77
# 539      Mananjary          41      MG  1600183264        81 -21.22   48.33
# 540         Agadez           0      NE  1600183264         8  19.75   10.25
# 541         Gwadar          58      PK  1600183265        69  25.12   62.33
#
#      Max Temp  Wind Speed
# 0       53.76        9.10
# 1       82.40       12.75
# 2       60.01       15.61
# 3       79.45        2.59
# 4       53.60        4.70
# ..        ...         ...
# 537     50.97        8.43
# 538     48.20        2.24
# 539     69.62       10.67
# 540    104.50        6.87
# 541     84.29        7.02
#
# [542 rows x 9 columns]

# %%
# Save city data into a csv file
weather_dict.to_csv("../output_data/cities.csv", index = False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_dict["Lat"], weather_dict["Wind Speed"], facecolor = "steelblue", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_dict.loc[weather_dict["Lat"] >= 0]
southern_hemisphere = weather_dict.loc[weather_dict["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.79

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"],southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.81

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.08

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.1

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.1

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.04

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.1

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.11
